# %% [markdown]
# ### **GOLD LAYER CLEANUP**

# %%
# %sql
Drop table if exists databricks_cata.gold.DimCustomers;

Drop table if exists databricks_cata.gold.factorders;

Drop table if exists databricks_cata.gold.dimproducts_stage;

Drop table if exists databricks_cata.gold.DimProducts;

# %%
dbutils.fs.rm("abfss://gold@databricksetehimanshi.dfs.core.windows.net/DimCustomers", recurse=True)
dbutils.fs.rm("abfss://gold@databricksetehimanshi.dfs.core.windows.net/FactOrders",recurse=True)
# Out:
# True

# %% [markdown]
# ### **SILVER LAYER CLEANUP**

# %%
# %sql
Drop table if exists databricks_cata.silver.customers_silver;

Drop table if exists databricks_cata.silver.products_silver;

Drop table if exists databricks_cata.silver.orders_silver;

Drop table if exists databricks_cata.silver.regions_silver;

# %%
#Deleting all the data inside "silver" conatiner in ADLS
dbutils.fs.rm("abfss://silver@databricksetehimanshi.dfs.core.windows.net/",recurse=True)
# Out:
# True

# %% [markdown]
# ### **BRONZE LAYER CLEANUP**

# %%
#Deleting all the data inside "bronze" conatiner in ADLS
dbutils.fs.rm("abfss://bronze@databricksetehimanshi.dfs.core.windows.net/",recurse=True)
# Out:
# True
